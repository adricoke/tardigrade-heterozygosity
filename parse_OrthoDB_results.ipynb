# %%
print(len(single_copy_metazoa))
# Out:
# 894

# %%
# fasta = requests.get('https://v101.orthodb.org/pgrest/rpc/fasta?id=615596at33208&species=7227')

# %%
# with open ("orthoDB/615596at33208.fasta", 'wb') as f:
#     f.write(fasta.content)

# %% [markdown]
# Loop through list of OrthoDB cluster id's and for each, use OrthoID's API interface (where this url will output a fasta file) to get fasta files for each gene ID with Drosophila melanogaster sequence:

# %%
for i in single_copy_metazoa:
    url = f"https://v101.orthodb.org/pgrest/rpc/fasta?id={i}&species=7227"
    fasta = requests.get(url)
    with open (f"orthoDB/{i}.fasta", 'wb') as f:
        f.write(fasta.content)

# %% [markdown]
# Next: go through each fasta file and get rid of all species except for Drosophila melanogaster
#
# - open file as read
# - loop through lines
# - if line.startswith('>7227_0:0017ef'), keep this and next line. Delete others

# %%
# this works for one file
with open("orthoDB/123923at33208.fasta", 'r') as fin, open("D_melanogaster/123923at33208.fasta", 'w') as fout:
    for line in fin:
        if line.startswith('>7227_0:0017ef'):
            fout.write(line)
            fout.write(next(fin))
            # data[line] = f"{file[line+1]}"
            # print(data)

# %%
# ran this loop on 7/20/22
count = 0
for i in single_copy_metazoa:
    with open(f"orthoDB/{i}.fasta", 'r') as fin, open(f"D_melanogaster/{i}.fasta", 'w') as fout:
        for line in fin:
            if line.startswith('>7227'):
                # print(line)
                fout.write(line)
                fout.write(next(fin))
                count += 1
print(count)
# Out:
# 873

# %% [markdown]
# 7/20/22
#
# Next we will generate a list of the pub_gene_id's from each of the 873 genes.
#
# Unfortunately, the format of this ID is not consistent. Only FlyBase ID's can be used to easily get DNA sequence.

# %%
import ast

# %%
# goal: make a list of FlyBase IDs for each gene in the D_melanogaster directory
count = 0
geneIDs = []
for i in single_copy_metazoa:
    with open(f"D_melanogaster/{i}.fasta", 'r') as f: # open each file
        for line in f:
            if line.startswith('>7227'):
                l = line[15:] # remove the first 15 characters
                l = ast.literal_eval(l) # convert to a dictionary
                # now we want to make a list of the pub_gene_ids
                geneIDs.append(l['pub_gene_id'])
                count += 1
print(count) # expect 873, same as above
print(geneIDs)
# Out:
# 873
# ...

# %%
FlyBaseIDs = []
for i in geneIDs:
    if 'FB' in i:
        FlyBaseIDs.append(i)
print(FlyBaseIDs)
print(len(FlyBaseIDs))
# 158 out of 873 genes include FlyBase IDs. For now, we can use these to go forward.
# Out:
# ['FBpp0082298', 'Dmel\\CG17219;FBpp0077335', 'FBpp0271702', 'DRG family regulatory protein 1 homolog;FBpp0087806', 'FBpp0087252', 'FBpp0081608', 'CG12863-RA;FBpp0086629', 'FBpp0081683', 'FBpp0079780', 'cactin;cactin-RA;FBpp0309346', 'BcDNA:LD45688;CG8038-RA;FBpp0076478', 'FBpp0087677', 'FBpp0111291', 'Dmel\\CG6761;FBpp0076143', 'FBpp0307589;ORF2', 'FBpp0079258', 'FBpp0086984', 'Dmel\\CG4709;FBpp0310303', 'FBXO9', 'FBpp0297722', 'FBpp0087681', 'FBpp0311708', 'FBpp0086132', 'FBpp0307719', 'CG8611-RB;FBpp0074214', 'FBpp0081652', 'FBpp0081434', 'FBpp0072768', 'FBpp0085119', 'Dmel\\CG1532;FBpp0308695', 'FBpp0078433;RpII18', 'FBpp0085330', 'FBpp0084724', 'FBpp0072907', 'BcDNA:RE09173;FBpp0297292', 'FBpp0078279', 'FBpp0289552', 'CG4679-RA;FBpp0086872', 'FBpp0303475', 'FBpp0071240', 'FBpp0072117', 'FBpp0112548', 'CG7741-RB;FBpp0087219', 'CG1796;FBpp0073459;Tango4', 'FBpp0086486', 'FBpp0084244', 'FBpp0079352;PrBP', 'FBpp0309955', 'FBpp0085589', 'FBpp0075250;IntS9', 'Dmel\\CG17514;FBpp0112471'
# ...

# %%
import copy

# %%
#clean up the FlyBase IDs
old_FlyBaseIDs = copy.deepcopy(FlyBaseIDs)
FlyBaseIDs = []
for i in old_FlyBaseIDs:
    # remove all characters except for FBpp and following 7 digits
    for c in range(len(i)): # makes c an int
        if i[c] == "F" and i[c+1] == "B" and i[c+2] == "p" and i[c+3] == "p":
            new = i[c:(c+11)]
            FlyBaseIDs.append(new)
print(FlyBaseIDs)
# Out:
# ['FBpp0082298', 'FBpp0077335', 'FBpp0271702', 'FBpp0087806', 'FBpp0087252', 'FBpp0081608', 'FBpp0086629', 'FBpp0081683', 'FBpp0079780', 'FBpp0309346', 'FBpp0076478', 'FBpp0087677', 'FBpp0111291', 'FBpp0076143', 'FBpp0307589', 'FBpp0079258', 'FBpp0086984', 'FBpp0310303', 'FBpp0297722', 'FBpp0087681', 'FBpp0311708', 'FBpp0086132', 'FBpp0307719', 'FBpp0074214', 'FBpp0081652', 'FBpp0081434', 'FBpp0072768', 'FBpp0085119', 'FBpp0308695', 'FBpp0078433', 'FBpp0085330', 'FBpp0084724', 'FBpp0072907', 'FBpp0297292', 'FBpp0078279', 'FBpp0289552', 'FBpp0086872', 'FBpp0303475', 'FBpp0071240', 'FBpp0072117', 'FBpp0112548', 'FBpp0087219', 'FBpp0073459', 'FBpp0086486', 'FBpp0084244', 'FBpp0079352', 'FBpp0309955', 'FBpp0085589', 'FBpp0075250', 'FBpp0112471', 'FBpp0082457', 'FBpp0311683', 'FBpp0309945', 'FBpp0086674', 'FBpp0072898', 'FBpp0112104', 'FBpp0072033', 'FBpp0077998', 'FBpp0311588', 'FBpp0071449', 'FBpp0076589', 'FBpp0080676', 'FBpp0311888', 'FBpp0073805', 'FBpp0079623', 'FBpp0308524', 'FBpp00
# ...

# %%
# randomly choose 15 FlyBase IDs to use for BLAST analysis against Hypsibius
import random
selection = random.sample(FlyBaseIDs, 15)
print(selection)
# Out:
# ['FBpp0071240', 'FBpp0070646', 'FBpp0303475', 'FBpp0085129', 'FBpp0086132', 'FBpp0077335', 'FBpp0072216', 'FBpp0070969', 'FBpp0308695', 'FBpp0310578', 'FBpp0073196', 'FBpp0312167', 'FBpp0292328', 'FBpp0072768', 'FBpp0304680']
